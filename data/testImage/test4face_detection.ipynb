# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# 测试DeepFace库的人脸检测
img_path = "/mnt/MCP/Deepface/data/testImage/test3.jpg"
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

try:
    # 尝试使用extract_faces方法
    faces = DeepFace.extract_faces(img_path=img_path, detector_backend="opencv")
    print(f"检测到 {len(faces)} 个人脸")
    if len(faces) > 0:
        face = faces[0]["face"]
        plt.imshow(face)
        plt.show()
except Exception as e:
    print(f"错误: {e}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from deepface import DeepFace
#       2 import cv2
#       3 import matplotlib.pyplot as plt
#
# File ~/miniconda3/envs/myconda/lib/python3.10/site-packages/deepface/DeepFace.py:20
#      18 from deepface.commons import package_utils, folder_utils
#      19 from deepface.commons.logger import Logger
# ---> 20 from deepface.modules import (
#      21     modeling,
#      22     representation,
#      23     verification,
#      24     recognition,
#      25     demography,
#      26     detection,
#      27     streaming,
#      28     preprocessing,
#      29 )
#      30 from deepface import __version__
#      32 logger = Logger()
#
# File ~/miniconda3/envs/myconda/lib/python3.10/site-packages/deepface/modules/modeling.py:5
#       2 from typing import Any
#       4 # project dependencies
# ----> 5 from deepface.models.facial_recognition import (
#       6     VGGFace,
#       7     OpenFace,
#       8     FbDeepFace,
#       9     DeepID,
#      10     ArcFace,
#      11     SFace,
#      12     Dlib,
#      13     Facenet,
#      14     GhostFaceNet,
#      15     Buffalo_L
#      16 )
#      17 from deepface.models.face_detection import (
#      18     FastMtCnn,
#      19     MediaPipe,
#    (...)
#      27     CenterFace,
#      28 )
#      29 from deepface.models.demography import Age, Gender, Race, Emotion
#
# File ~/miniconda3/envs/myconda/lib/python3.10/site-packages/deepface/models/facial_recognition/VGGFace.py:9
#       7 # project dependencies
#       8 from deepface.commons import package_utils, weight_utils
# ----> 9 from deepface.modules import verification
#      10 from deepface.models.FacialRecognition import FacialRecognition
#      11 from deepface.commons.logger import Logger
#
# File ~/miniconda3/envs/myconda/lib/python3.10/site-packages/deepface/modules/verification.py:10
#       7 import numpy as np
#       9 # project dependencies
# ---> 10 from deepface.modules import representation, detection, modeling
#      11 from deepface.models.FacialRecognition import FacialRecognition
#      12 from deepface.commons.logger import Logger
#
# File ~/miniconda3/envs/myconda/lib/python3.10/site-packages/deepface/modules/representation.py:9
#       6 import numpy as np
#       8 # project dependencies
# ----> 9 from deepface.commons import image_utils
#      10 from deepface.modules import modeling, detection, preprocessing
#      11 from deepface.models.FacialRecognition import FacialRecognition
#
# File ~/miniconda3/envs/myconda/lib/python3.10/site-packages/deepface/commons/image_utils.py:12
#      10 import requests
#      11 import numpy as np
# ---> 12 import cv2
#      13 from PIL import Image
#      14 from werkzeug.datastructures import FileStorage
#
# ImportError: /root/miniconda3/envs/myconda/bin/../lib/libstdc++.so.6: version `GLIBCXX_3.4.30' not found (required by /root/miniconda3/envs/myconda/lib/python3.10/site-packages/../.././libQt6Test.so.6)
