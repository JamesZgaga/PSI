# %%
import os
import yaml
from PIL import Image
from collections import defaultdict

def load_yaml_config(config_path):
    """加载loopy.yaml配置文件，获取类别信息"""
    try:
        with open(config_path, 'r', encoding='utf-8') as f:
            config = yaml.safe_load(f)
        # 提取类别名称（确保与配置文件一致）
        class_names = config.get('names', [])
        num_classes = config.get('nc', len(class_names))
        print(f"成功加载配置文件：{config_path}")
        print(f"类别数量：{num_classes}")
        print(f"类别名称：{class_names}\n")
        return class_names
    except Exception as e:
        print(f"加载配置文件失败：{e}")
        return []

def get_file_list(folder, exts=('jpg', 'jpeg', 'png', 'bmp')):
    """获取指定文件夹下特定格式的文件列表（不含后缀）"""
    if not os.path.exists(folder):
        print(f"文件夹不存在：{folder}")
        return []
    # 只保留指定格式的文件，并提取文件名（不含后缀）
    file_list = []
    for file in os.listdir(folder):
        name, ext = os.path.splitext(file)
        if ext.lower().lstrip('.') in exts:
            file_list.append(name)
    return sorted(file_list)

def count_class_distribution(labels_folder, class_names):
    """统计标签文件中的类别分布"""
    class_counts = defaultdict(int)
    invalid_files = []  # 记录格式错误的标签文件
    
    if not os.path.exists(labels_folder):
        print(f"标签文件夹不存在：{labels_folder}")
        return class_counts, invalid_files
    
    # 遍历所有标签文件（假设标签为YOLO格式的txt文件）
    for label_file in os.listdir(labels_folder):
        if not label_file.endswith('.txt'):
            continue  # 只处理txt标签文件
        label_path = os.path.join(labels_folder, label_file)
        try:
            with open(label_path, 'r') as f:
                lines = f.readlines()
                # 假设每个图像对应一个表情（每行一个目标，取第一行的类别）
                if lines:
                    first_line = lines[0].strip().split()
                    if len(first_line) >= 1:  # 至少包含类别ID
                        class_id = int(first_line[0])
                        # 检查类别ID是否在有效范围内
                        if 0 <= class_id < len(class_names):
                            class_name = class_names[class_id]
                            class_counts[class_name] += 1
                        else:
                            invalid_files.append(f"{label_file}（无效类别ID：{class_id}）")
                    else:
                        invalid_files.append(f"{label_file}（标签格式错误，无内容）")
                else:
                    invalid_files.append(f"{label_file}（标签文件为空）")
        except Exception as e:
            invalid_files.append(f"{label_file}（读取错误：{str(e)}）")
    
    return class_counts, invalid_files

def check_image_sizes(image_folder, sample_size=100):
    """抽样检查图像尺寸分布（避免全量检查耗时）"""
    if not os.path.exists(image_folder):
        return {}
    image_sizes = defaultdict(int)
    image_files = [f for f in os.listdir(image_folder) if f.lower().endswith(('jpg', 'jpeg', 'png'))]
    # 抽样（最多检查sample_size个图像）
    sample_files = image_files[:sample_size]
    for img_file in sample_files:
        img_path = os.path.join(image_folder, img_file)
        try:
            with Image.open(img_path) as img:
                size = img.size  # (width, height)
                image_sizes[size] += 1
        except Exception as e:
            print(f"读取图像失败（{img_file}）：{e}")
    return image_sizes

def analyze_dataset(data_type, root_dir, class_names):
    """分析单个数据集（训练集/测试集）"""
    print(f"\n===== 开始分析 {data_type} 集 =====")
    # 定义图像和标签路径（根据实际目录结构：train/image 和 train/labels）
    image_dir = os.path.join(root_dir, data_type, 'image')
    labels_dir = os.path.join(root_dir, data_type, 'labels')
    
    # 1. 获取图像和标签文件列表（不含后缀）
    image_names = get_file_list(image_dir)
    label_names = get_file_list(labels_dir, exts=('txt',))  # 标签是txt文件
    print(f"图像文件数量：{len(image_names)}（路径：{image_dir}）")
    print(f"标签文件数量：{len(label_names)}（路径：{labels_dir}）")
    
    # 2. 检查图像与标签是否一一对应
    images_set = set(image_names)
    labels_set = set(label_names)
    # 只有图像没有标签的文件
    missing_labels = images_set - labels_set
    # 只有标签没有图像的文件
    missing_images = labels_set - images_set
    print(f"缺失标签的图像数量：{len(missing_labels)}（示例：{list(missing_labels)[:5]}）")
    print(f"缺失图像的标签数量：{len(missing_images)}（示例：{list(missing_images)[:5]}）")
    
    # 3. 统计类别分布
    class_counts, invalid_files = count_class_distribution(labels_dir, class_names)
    print("\n类别分布：")
    for class_name in class_names:  # 按配置文件顺序输出
        print(f"  {class_name}: {class_counts.get(class_name, 0)}")
    if invalid_files:
        print(f"\n无效标签文件（共{len(invalid_files)}个）：{invalid_files[:5]}...")  # 只显示前5个
    
    # 4. 抽样检查图像尺寸
    image_sizes = check_image_sizes(image_dir)
    if image_sizes:
        print("\n抽样图像尺寸分布（最多100张）：")
        for size, count in image_sizes.items():
            print(f"  尺寸 {size}（宽x高）：{count} 张")
    
    print(f"===== {data_type} 集分析结束 =====\n")

if __name__ == "__main__":
    # 数据集根目录（根据你的路径修改，当前为/mnt/MCP/Deepface/data/expression）
    dataset_root = "/mnt/MCP/Deepface/data/expression"
    # 配置文件路径
    config_path = os.path.join(dataset_root, "loopy.yaml")
    
    # 1. 加载配置文件获取类别信息
    class_names = load_yaml_config(config_path)
    if not class_names:
        print("无法获取类别信息，退出分析")
        exit(1)
    
    # 2. 分别分析训练集和测试集
    analyze_dataset("train", dataset_root, class_names)
    analyze_dataset("test", dataset_root, class_names)
    
    print("数据集分析完成！")
# Out:
# 成功加载配置文件：/mnt/MCP/Deepface/data/expression/loopy.yaml
# 类别数量：7
# 类别名称：['Surprise', 'Fear', 'Disgust', 'Happiness', 'Sadness', 'Anger', 'Neutral']
#
#
# ===== 开始分析 train 集 =====
# 图像文件数量：12271（路径：/mnt/MCP/Deepface/data/expression/train/image）
# 标签文件数量：12271（路径：/mnt/MCP/Deepface/data/expression/train/labels）
# 缺失标签的图像数量：0（示例：[]）
# 缺失图像的标签数量：0（示例：[]）
#
# 类别分布：
#   Surprise: 1290
#   Fear: 281
#   Disgust: 717
#   Happiness: 4772
#   Sadness: 1982
#   Anger: 705
#   Neutral: 2524
#
# 抽样图像尺寸分布（最多100张）：
#   尺寸 (384, 576)（宽x高）：1 张
#   尺寸 (127, 190)（宽x高）：1 张
#   尺寸 (168, 252)（宽x高）：1 张
#   尺寸 (241, 361)（宽x高）：1 张
#   尺寸 (490, 736)（宽x高）：1 张
#   尺寸 (180, 270)（宽x高）：1 张
#   尺寸 (672, 1008)（宽x高）：1 张
#   尺寸 (105, 158)（宽x高）：2 张
#   尺寸 (750, 1125)（宽x高）：1 张
#   尺寸 (794, 1191)（宽x高）：1 张
#   尺寸 (220, 331)（宽x高）：1 张
#   尺寸 (533, 800)（宽x高）：1 张
#   尺寸 (1212, 1818)（宽x高）：1 张
#   尺寸 (264, 396)（宽x高）：1 张
#   尺寸 (218, 327)（宽x高）：3 张
#   尺寸 (181, 272)（宽x高）：1 张
#   尺寸 (248, 371)（宽x高）：1 张
#   尺寸 (70, 105)（宽x高）：1 张
#   尺寸 (115, 172)（宽x高）：1 张
#   尺寸 (307, 460)（宽x高）：1 张
#   尺寸 (943, 1414)（宽x高）：1 张
#   尺寸 (475, 713)（宽x高）：1 张
#   尺寸 (213, 320)（宽x高）：1 张
#   尺寸 (220, 330)（宽x高）：1 张
#   尺寸 (216, 324)（宽x高）：1 张
#   尺寸 (156, 234)（宽x高）：1 张
#   尺寸 (480, 720)（宽x高）：1 张
#   尺寸 (56, 84)（宽x高）：1 张
#   尺寸 (576, 864)（宽x高）：1 张
#   尺寸 (578, 867)（宽x高）：1 张
#   尺寸 (147, 221)（宽x高）：1 张
#   尺寸 (187, 281)（宽x高）：1 张
#   尺寸 (141, 212)（宽x高）：1 张
#   尺寸 (108, 163)（宽x高）：1 张
#   尺寸 (382, 574)（宽x高）：1 张
#   尺寸 (103, 154)（宽x高）：1 张
#   尺寸 (69, 104)（宽x高）：1 张
#   尺寸 (449, 673)（宽x高）：1 张
#   尺寸 (91, 136)（宽x高）：1 张
#   尺寸 (253, 380)（宽x高）：1 张
#   尺寸 (98, 147)（宽x高）：1 张
#   尺寸 (518, 777)（宽x高）：1 张
#   尺寸 (1118, 1677)（宽x高）：1 张
#   尺寸 (494, 741)（宽x高）：1 张
#   尺寸 (507, 761)（宽x高）：1 张
#   尺寸 (112, 169)（宽x高）：2 张
#   尺寸 (580, 871)（宽x高）：1 张
#   尺寸 (321, 482)（宽x高）：1 张
#   尺寸 (1156, 1735)（宽x高）：1 张
#   尺寸 (165, 248)（宽x高）：1 张
#   尺寸 (722, 1083)（宽x高）：1 张
#   尺寸 (318, 477)（宽x高）：1 张
#   尺寸 (129, 194)（宽x高）：1 张
#   尺寸 (812, 1218)（宽x高）：1 张
#   尺寸 (55, 83)（宽x高）：1 张
#   尺寸 (288, 432)（宽x高）：1 张
#   尺寸 (942, 1414)（宽x高）：1 张
#   尺寸 (198, 297)（宽x高）：1 张
#   尺寸 (914, 1372)（宽x高）：1 张
#   尺寸 (184, 276)（宽x高）：1 张
#   尺寸 (734, 1101)（宽x高）：1 张
#   尺寸 (693, 1040)（宽x高）：1 张
#   尺寸 (474, 712)（宽x高）：1 张
#   尺寸 (266, 399)（宽x高）：1 张
#   尺寸 (1016, 1524)（宽x高）：1 张
#   尺寸 (273, 409)（宽x高）：1 张
#   尺寸 (603, 905)（宽x高）：1 张
#   尺寸 (650, 975)（宽x高）：1 张
#   尺寸 (1102, 1654)（宽x高）：1 张
#   尺寸 (146, 219)（宽x高）：1 张
#   尺寸 (2019, 3028)（宽x高）：1 张
#   尺寸 (1555, 2332)（宽x高）：1 张
#   尺寸 (520, 781)（宽x高）：1 张
#   尺寸 (232, 348)（宽x高）：1 张
#   尺寸 (120, 180)（宽x高）：1 张
#   尺寸 (117, 176)（宽x高）：1 张
#   尺寸 (158, 237)（宽x高）：3 张
#   尺寸 (894, 1336)（宽x高）：1 张
#   尺寸 (1125, 1688)（宽x高）：1 张
#   尺寸 (71, 106)（宽x高）：1 张
#   尺寸 (309, 464)（宽x高）：1 张
#   尺寸 (489, 734)（宽x高）：1 张
#   尺寸 (256, 385)（宽x高）：1 张
#   尺寸 (832, 1248)（宽x高）：1 张
#   尺寸 (84, 126)（宽x高）：1 张
#   尺寸 (249, 374)（宽x高）：1 张
#   尺寸 (526, 789)（宽x高）：1 张
#   尺寸 (740, 1111)（宽x高）：1 张
#   尺寸 (316, 475)（宽x高）：1 张
#   尺寸 (549, 824)（宽x高）：1 张
#   尺寸 (1533, 2300)（宽x高）：1 张
#   尺寸 (900, 1350)（宽x高）：1 张
#   尺寸 (95, 143)（宽x高）：1 张
#   尺寸 (292, 439)（宽x高）：1 张
# ===== train 集分析结束 =====
#
#
# ===== 开始分析 test 集 =====
# 图像文件数量：3068（路径：/mnt/MCP/Deepface/data/expression/test/image）
# 标签文件数量：3068（路径：/mnt/MCP/Deepface/data/expression/test/labels）
# 缺失标签的图像数量：0（示例：[]）
# 缺失图像的标签数量：0（示例：[]）
#
# 类别分布：
#   Surprise: 329
#   Fear: 74
#   Disgust: 160
#   Happiness: 1185
#   Sadness: 478
#   Anger: 162
#   Neutral: 680
#
# 抽样图像尺寸分布（最多100张）：
#   尺寸 (458, 687)（宽x高）：1 张
#   尺寸 (672, 1009)（宽x高）：1 张
#   尺寸 (1053, 1580)（宽x高）：1 张
#   尺寸 (136, 205)（宽x高）：1 张
#   尺寸 (600, 900)（宽x高）：1 张
#   尺寸 (741, 1112)（宽x高）：2 张
#   尺寸 (1233, 1850)（宽x高）：1 张
#   尺寸 (225, 338)（宽x高）：1 张
#   尺寸 (135, 202)（宽x高）：1 张
#   尺寸 (290, 435)（宽x高）：3 张
#   尺寸 (249, 374)（宽x高）：1 张
#   尺寸 (645, 968)（宽x高）：1 张
#   尺寸 (1352, 2028)（宽x高）：1 张
#   尺寸 (160, 241)（宽x高）：1 张
#   尺寸 (97, 146)（宽x高）：1 张
#   尺寸 (86, 129)（宽x高）：1 张
#   尺寸 (537, 806)（宽x高）：1 张
#   尺寸 (595, 893)（宽x高）：1 张
#   尺寸 (129, 194)（宽x高）：1 张
#   尺寸 (493, 740)（宽x高）：1 张
#   尺寸 (487, 730)（宽x高）：1 张
#   尺寸 (112, 169)（宽x高）：2 张
#   尺寸 (575, 863)（宽x高）：1 张
#   尺寸 (363, 545)（宽x高）：1 张
#   尺寸 (496, 745)（宽x高）：1 张
#   尺寸 (698, 1047)（宽x高）：1 张
#   尺寸 (285, 428)（宽x高）：3 张
#   尺寸 (74, 111)（宽x高）：1 张
#   尺寸 (156, 234)（宽x高）：1 张
#   尺寸 (151, 226)（宽x高）：1 张
#   尺寸 (239, 358)（宽x高）：1 张
#   尺寸 (950, 1425)（宽x高）：1 张
#   尺寸 (153, 229)（宽x高）：1 张
#   尺寸 (230, 345)（宽x高）：2 张
#   尺寸 (642, 963)（宽x高）：1 张
#   尺寸 (189, 284)（宽x高）：1 张
#   尺寸 (115, 172)（宽x高）：2 张
#   尺寸 (940, 1411)（宽x高）：1 张
#   尺寸 (444, 666)（宽x高）：1 张
#   尺寸 (372, 558)（宽x高）：1 张
#   尺寸 (1015, 1522)（宽x高）：1 张
#   尺寸 (187, 280)（宽x高）：1 张
#   尺寸 (696, 1044)（宽x高）：1 张
#   尺寸 (283, 424)（宽x高）：1 张
#   尺寸 (88, 133)（宽x高）：1 张
#   尺寸 (158, 237)（宽x高）：1 张
#   尺寸 (333, 500)（宽x高）：1 张
#   尺寸 (465, 698)（宽x高）：1 张
#   尺寸 (751, 1126)（宽x高）：1 张
#   尺寸 (900, 1350)（宽x高）：1 张
#   尺寸 (254, 381)（宽x高）：1 张
#   尺寸 (1079, 1619)（宽x高）：1 张
#   尺寸 (681, 1021)（宽x高）：1 张
#   尺寸 (609, 914)（宽x高）：2 张
#   尺寸 (782, 1173)（宽x高）：1 张
#   尺寸 (1404, 2106)（宽x高）：1 张
#   尺寸 (422, 633)（宽x高）：1 张
#   尺寸 (256, 385)（宽x高）：1 张
#   尺寸 (309, 464)（宽x高）：1 张
#   尺寸 (361, 542)（宽x高）：1 张
#   尺寸 (100, 151)（宽x高）：1 张
#   尺寸 (1425, 2138)（宽x高）：1 张
#   尺寸 (354, 531)（宽x高）：1 张
#   尺寸 (938, 1407)（宽x高）：1 张
#   尺寸 (708, 1062)（宽x高）：1 张
#   尺寸 (555, 833)（宽x高）：1 张
#   尺寸 (415, 622)（宽x高）：1 张
#   尺寸 (117, 176)（宽x高）：1 张
#   尺寸 (717, 1075)（宽x高）：1 张
#   尺寸 (192, 288)（宽x高）：1 张
#   尺寸 (686, 1029)（宽x高）：1 张
#   尺寸 (91, 136)（宽x高）：1 张
#   尺寸 (94, 142)（宽x高）：1 张
#   尺寸 (684, 1027)（宽x高）：1 张
#   尺寸 (1636, 2455)（宽x高）：1 张
#   尺寸 (957, 1436)（宽x高）：1 张
#   尺寸 (367, 550)（宽x高）：1 张
#   尺寸 (569, 854)（宽x高）：1 张
#   尺寸 (991, 1486)（宽x高）：1 张
#   尺寸 (162, 239)（宽x高）：1 张
#   尺寸 (79, 118)（宽x高）：1 张
#   尺寸 (972, 1458)（宽x高）：1 张
#   尺寸 (778, 1167)（宽x高）：1 张
#   尺寸 (1012, 1519)（宽x高）：1 张
#   尺寸 (792, 1188)（宽x高）：1 张
#   尺寸 (180, 270)（宽x高）：1 张
#   尺寸 (201, 302)（宽x高）：1 张
#   尺寸 (460, 691)（宽x高）：1 张
#   尺寸 (727, 1090)（宽x高）：1 张
#   尺寸 (992, 1488)（宽x高）：1 张
#   尺寸 (1075, 1612)（宽x高）：1 张
# ===== test 集分析结束 =====
#
# 数据集分析完成！
